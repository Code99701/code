# %%
#### using the os module
import os
cwd = os.getcwd()
print(f"CURRENT WORKING DIRECTORY IS: {cwd}")
# Out:
# CURRENT WORKING DIRECTORY IS: e:\ml course\code\6-File Handling

# %%
## create a new directory
new_directory = "package"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' created.")
# Out:
# Directory 'package' created.

# %%
## listing Files and Directories
items = os.listdir('.')
print(items)
# Out:
# ['6.1-fileoperation.ipynb', '6.2-filepath.ipynb', 'destination.txt', 'example.bin', 'example.txt', 'package']

# %%
### Joining Paths

dir_name = "folder"
file_name = "test.txt"
full_path = os.path.join(dir_name, file_name)
print(full_path)
# Out:
# folder\test.txt

# %%
dir_name = "folder"
file_name = "test.txt"
full_path = os.path.join(os.getcwd(), dir_name, file_name)
print(full_path)
# Out:
# e:\ml course\code\6-File Handling\folder\test.txt

# %%
path = 'example1.txt'
if os.path.exists(path):
    print(f"The file '{path}' exists.")
else:
    print(f"The file '{path}' does not exists.")
# Out:
# The file 'exampl2e.txt' does not exists.

# %%
#Checking if a path is a file or directory
import os

path = 'example.txt'
if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory.")
else:
    print(f"The path '{path}' is neither a file nor a directory.")

# %%
## getting the absolute path
query_path = 'example.txt'
absolute_path = os.path.abspath(query_path)
print(absolute_path)
# Out:
# e:\ml course\code\6-File Handling\example.txt

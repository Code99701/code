# %%
## if statement 
age = 20

if age >= 18:
    print("you are allowed to vote in the elections")
# Out:
# you are allowed to vote in the elections

# %%
age >= 18
# Out:
# True

# %%
## else
## The else statement executes a block if the condition in the if statement is false.

age = 16

if age>=18:
 print("you are eligible for porn")
else:
 print("see cartoon")
# Out:
# see cartoon

# %%
## elif
## The elif statement allows you to check multiple conditions. It stands for "else if"

age = 20

if age < 13:
    print("You are a child")
elif age < 18:
    print("You are a teenager")
else:
    print("You are an adult")

# %%
## Nested Conditional Statements
# you can place on or more if , elif or else statements inside another if, elif or else statement to create nested conndition statement
## number even, odd, negative

num = int(input("Enter the number"))

if num >= 0:
    print("The number is positive")
    if num%2 == 0:
        print("The number is even")
    else:
        print("The number is odd")
else:
    print("The number is zero or negative")
# Out:
# The number is positive
# The number is even

# %%
## Practical Examples

## Determine if a year is a leap year using nested conditional statement

year = int(input("Enter the Year"))

if year%4 == 0:
    if year%100 == 0:
        if year%400 == 0:
            print(year,"is a leap year")
        else:
            print(year,"is  not a leap year")
    else:
        print(year,"is a leap year")
else:
    print(year,"is not a leap year")
# Out:
# 2028 is a leap year

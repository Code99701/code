# %%
## Basic Syntax Rules IN Python
## Case Sensitivity Python is Case Sensitive

name ="Arnav"
Name ="Mahajan"

print(name)
print(Name)
# Out:
# Arnav
# Mahajan

# %%
## Indentation 
## python uses identation to define of blocks of code. consistent use of spaces (commonly 4) or a tab is required.

age =14
if age>15:
    print(age)
else:
    print("not eligible")
# Out:
# not eligible

# %%
## this is a single line comment
print("Hello world")
# Out:
# Hello world

# %%
## Line continuation
## Use a backslash (\) to continue  a statement to the next line


total=1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %%
## Multiply statements on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
## understand semantics In python
# varibles assignment
age = 32 ## age is an integer
name = "Arnav" ##name is a string

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## Type Inference
variable = 10
print(type(variable))
variable ="Arnav"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 a = b
#
# NameError: name 'b' is not defined

# %%
## code examples of idetation
if True:
    print("Correct Indentation")
    if False:
        print("this wont print")
    print("this will print")
print("Outside the if block")
# Out:
# Correct Indentation
# this will print
# Outside the if block

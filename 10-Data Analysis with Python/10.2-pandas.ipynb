# %% [markdown]
# #### Pandas-Dataframe And Series

# %% [markdown]
# Pandas is a powerful data manipulation library in Python, widely used for data analysis and data cleaning. It provides two primary data structures: Series and DataFrame. A Series is a one-dimensional array-like object, while a DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns).

# %%
import pandas as pd

# %%
## Series
##A Pandas Series is a one-dimensional array-like object that can hold any data type. It is similar to a column in a table.

import pandas as pd
data = [1,2,3,4,5]
series = pd.Series(data)
print("series \n",series)
print(type(series))
# Out:
# series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
## Create a series from dictionary
data = {'a':1,'b':2,'c':3}
series_dict = pd.Series(data)
print(series_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = [10,20,30]
index = ['a','b','c']
pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
## Dataframe
## create  a Dataframe from a dictionary of list

data={
    'Name':['Arnav','John','Jack'],
    'Age':[19,30,45],
    'city':['Indore','New York','Florida']
}
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name  Age      city
# 0  Arnav   19    Indore
# 1   John   30  New York
# 2   Jack   45   Florida
# <class 'pandas.core.frame.DataFrame'>

# %%
import numpy as np

np.array(df)
# Out:
# array([['Arnav', 19, 'Indore'],
#        ['John', 30, 'New York'],
#        ['Jack', 45, 'Florida']], dtype=object)

# %%
# Create a Data frame From a List of Dictionaries

data = [
    {'Name': 'Arnav', 'Age': '19', 'City': 'Indore'},
    {'Name': 'John', 'Age': 34, 'City': 'Bangalore'},
    {'Name': 'Bappy', 'Age': 32, 'City': 'Bangalore'},
    {'Name': 'Jack', 'Age': 32, 'City': 'Bangalore'}
]

df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name Age       City
# 0  Arnav  19     Indore
# 1   John  34  Bangalore
# 2  Bappy  32  Bangalore
# 3   Jack  32  Bangalore
# <class 'pandas.core.frame.DataFrame'>

# %%
df = pd.read_csv('Orders.csv')
df.head()
# Out:
#   Order ID  Order Date CustomerName           State     City
# 0  B-26055  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 1  B-25993  03-02-2018       Madhav           Delhi    Delhi
# 2  B-25973  24-01-2018  Madan Mohan   Uttar Pradesh  Mathura
# 3  B-25923  27-12-2018        Gopal     Maharashtra   Mumbai
# 4  B-25757  21-08-2018     Vishakha  Madhya Pradesh   Indore

# %%
df.tail()
# Out:
#     Order ID  Order Date CustomerName             State     City
# 495  B-25742  03-08-2018       Ashwin               Goa      Goa
# 496  B-26088  26-03-2018       Bhavna            Sikkim  Gangtok
# 497  B-25707  01-07-2018      Shivani       Maharashtra   Mumbai
# 498  B-25758  22-08-2018      Shubham  Himachal Pradesh    Simla
# 499  B-26095  28-03-2018      Monisha         Rajasthan   Jaipur

# %%
df
# Out:
#     Order ID  Order Date CustomerName             State     City
# 0    B-26055  10-03-2018    Harivansh     Uttar Pradesh  Mathura
# 1    B-25993  03-02-2018       Madhav             Delhi    Delhi
# 2    B-25973  24-01-2018  Madan Mohan     Uttar Pradesh  Mathura
# 3    B-25923  27-12-2018        Gopal       Maharashtra   Mumbai
# 4    B-25757  21-08-2018     Vishakha    Madhya Pradesh   Indore
# ..       ...         ...          ...               ...      ...
# 495  B-25742  03-08-2018       Ashwin               Goa      Goa
# 496  B-26088  26-03-2018       Bhavna            Sikkim  Gangtok
# 497  B-25707  01-07-2018      Shivani       Maharashtra   Mumbai
# 498  B-25758  22-08-2018      Shubham  Himachal Pradesh    Simla
# 499  B-26095  28-03-2018      Monisha         Rajasthan   Jaipur
#
# [500 rows x 5 columns]

# %%
### Accessing Data from Dataframe
df['Name']
# Out:
# 0    Arnav
# 1     John
# 2    Bappy
# 3     Jack
# Name: Name, dtype: object

# %%
df.loc[0][0]
# Out:
# C:\Users\ARNAV MAHAJAN\AppData\Local\Temp\ipykernel_22320\2527876973.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[0][0]
# 'B-26055'

# %%
df.iloc[0][2]
# Out:
# C:\Users\ARNAV MAHAJAN\AppData\Local\Temp\ipykernel_22320\2519637664.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][2]
# 'Harivansh'

# %%
df
# Out:
#     Name Age       City
# 0  Arnav  19     Indore
# 1   John  34  Bangalore
# 2  Bappy  32  Bangalore
# 3   Jack  32  Bangalore

# %%
### Accessing a Specified element
df.at[2,"Name"]
# Out:
# 'Bappy'

# %%
## Accessing a specified element using int
df.iat[2,2]
# Out:
# 'Bangalore'

# %%
df
# Out:
#     Name Age       City
# 0  Arnav  19     Indore
# 1   John  34  Bangalore
# 2  Bappy  32  Bangalore
# 3   Jack  32  Bangalore

# %%
### data manipulation with dataframe
df
# Out:
#     Name Age       City
# 0  Arnav  19     Indore
# 1   John  34  Bangalore
# 2  Bappy  32  Bangalore
# 3   Jack  32  Bangalore

# %%
## Adding a column
df['Salary'] = [50000,60000,70000,80000]
df
# Out:
#     Name Age       City  Salary
# 0  Arnav  19     Indore   50000
# 1   John  34  Bangalore   60000
# 2  Bappy  32  Bangalore   70000
# 3   Jack  32  Bangalore   80000

# %%
## Remove a column
df.drop('Salary',axis= 1,inplace=True)

# %%
df
# Out:
#     Name Age       City
# 0  Arnav  19     Indore
# 1   John  34  Bangalore
# 2  Bappy  32  Bangalore
# 3   Jack  32  Bangalore

# %%
## add age to the column
df['Age'] = df['Age'].astype(int) + 1
df
# Out:
#     Name  Age       City
# 0  Arnav   20     Indore
# 1   John   35  Bangalore
# 2  Bappy   33  Bangalore
# 3   Jack   33  Bangalore

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#     Name  Age       City
# 1   John   35  Bangalore
# 2  Bappy   33  Bangalore
# 3   Jack   33  Bangalore

# %%
df = pd.read_csv('Orders.csv')
df.head(5)
# Out:
#   Order ID  Order Date CustomerName           State     City
# 0  B-26055  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 1  B-25993  03-02-2018       Madhav           Delhi    Delhi
# 2  B-25973  24-01-2018  Madan Mohan   Uttar Pradesh  Mathura
# 3  B-25923  27-12-2018        Gopal     Maharashtra   Mumbai
# 4  B-25757  21-08-2018     Vishakha  Madhya Pradesh   Indore

# %%
# Display the data types of each column
print("Data types:\n", df.dtypes)

# Describe the DataFrame
print("Statistical summary:\n", df.describe())
# Out:
# Data types:
#  Order ID        object
# Order Date      object
# CustomerName    object
# State           object
# City            object
# dtype: object
# Statistical summary:
#         Order ID  Order Date CustomerName        State    City
# count       500         500          500          500     500
# unique      500         307          336           19      25
# top     B-26055  24-11-2018       Shreya  Maharashtra  Indore
# freq          1           7            6           94      71

# %%
df.describe()
# Out:
#        Order ID  Order Date CustomerName        State    City
# count       500         500          500          500     500
# unique      500         307          336           19      25
# top     B-26055  24-11-2018       Shreya  Maharashtra  Indore
# freq          1           7            6           94      71

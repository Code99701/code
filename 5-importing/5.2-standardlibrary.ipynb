# %% [markdown]
# #### Standard Library Overview

# %% [markdown]
# Python's Standard Library is a vast collection of modules and packages that come bundled with Python, providing a wide range of functionalities out of the box. Here's an overview of some of the most commonly used modules and packages in the Python Standard Library.

# %%
import array
arr = array.array('i', [1, 2, 3, 4, 5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math
print(math.sqrt(16))        
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## random 

import random
print(random.randint(1, 10))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 7
# banana

# %%
### file and directory Access
import os
print(os.getcwd())
# Out:
# e:\ml course\code\5-importing

# %%
os.mkdir('new_directory')

# %%
## High level operations on files and collections of files
import shutil
shutil.copy('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Seralization
import json
data = {'name': 'Alice', 'age': 30, 'city': 'New York'}
json_string = json.dumps(data)
print(json_string)
print(type(json_string))

parsed_data= json.loads(json_string)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Alice", "age": 30, "city": "New York"}
# <class 'str'>
# {'name': 'Alice', 'age': 30, 'city': 'New York'}
# <class 'dict'>

# %%
## csv file handling

import csv
with open('data.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Age', 'City'])
    writer.writerow(['Alice', 30, 'New York'])
    writer.writerow(['Bob', 25, 'Los Angeles'])

with open('data.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'City']
# ['Alice', '30', 'New York']
# ['Bob', '25', 'Los Angeles']

# %%
## Datetime

from datetime import datetime, timedelta

now = datetime.now()
print("Current date and time:", now)

yesterday = now - timedelta(days=1)

print("Yesterday's date and time:", yesterday)
# Out:
# Current date and time: 2026-04-14 16:53:16.347843
# Yesterday's date and time: 2026-04-13 16:53:16.347843

# %%
## time
import time
print("Current time:", time.time())
time.sleep(2)
print("Current time after 2 seconds:", time.time())
# Out:
# Current time: 1776165849.8661704
# Current time after 2 seconds: 1776165851.8667574

# %%
## regular expressions
import re

pattern = r'\d+'
text = "there are 123 apples and 456 oranges"
match = re.search(pattern, text)
print(match.group())
# Out:
# 123
